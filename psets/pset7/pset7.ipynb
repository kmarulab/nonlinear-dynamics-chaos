# %%
import numpy as np
from scipy.integrate import solve_ivp
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

def lorenz_rhs(t,state,s,r,b):
    # Break up state variable into 3:
    x,y,z = state

    dxdt = s*(y-x)
    dydt = r*x - y - x*z
    dzdt = x*y - b*z

    # Assemble
    return [dxdt,dydt,dzdt]

# Initial condition
y0 = [0, 1, 20]

# Time span for the solution (start time, end time)
t_span = (0, 100)

# Plot the solution at the following times:
tvals = np.linspace(0,t_span[1],10000)

# Solve the ODE
solution1 = solve_ivp(lorenz_rhs, # system of equations
                      t_span, # time span of integration
                      y0, # initial conditions
                      args=(10,21.5,8/3), # parameters
                      t_eval=tvals, # times at which to store solution
                      method='RK45' # method of integration
                     )



plt.plot(solution1.y[0],solution1.y[2])
plt.xlabel('x')
plt.ylabel('z')
plt.show()

plt.title('Lorenz Equations $\sigma$=10, b=8/3, r=21.5')
plt.plot(tvals, solution1.y[1], label = 'y')
plt.plot(tvals, solution1.y[2], label = 'z')
plt.legend()
plt.show()
# Out:
# <>:42: SyntaxWarning: invalid escape sequence '\s'
# <>:42: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_22492/4288059444.py:42: SyntaxWarning: invalid escape sequence '\s'
#   plt.title('Lorenz Equations $\sigma$=10, b=8/3, r=21.5')

# %%
# Initial condition
y0 = [0, 1, 0]

# Time span for the solution (start time, end time)
t_span = (0, 20)

# Plot the solution at the following times:
tvals = np.linspace(0,t_span[1],10000)

# Solve the ODE
solution2 = solve_ivp(lorenz_rhs, # system of equations
                      t_span, # time span of integration
                      y0, # initial conditions
                      args=(10,14,8/3), # parameters
                      t_eval=tvals, # times at which to store solution
                      method='RK45' # method of integration
                     )



plt.plot(solution2.y[0],solution2.y[2])
plt.xlabel('x')
plt.ylabel('z')
plt.show()

plt.title('Lorenz Equations $\sigma$=10, b=8/3, r=14')
plt.plot(tvals, solution2.y[1], label = 'y')
plt.plot(tvals, solution2.y[2], label = 'z')
plt.legend()
plt.show()
# Out:
# <>:26: SyntaxWarning: invalid escape sequence '\s'
# <>:26: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_30070/1879122890.py:26: SyntaxWarning: invalid escape sequence '\s'
#   plt.title('Lorenz Equations $\sigma$=10, b=8/3, r=14')
